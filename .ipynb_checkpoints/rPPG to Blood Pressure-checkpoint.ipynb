# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-data" data-toc-modified-id="Load-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Filtering" data-toc-modified-id="Filtering-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Filtering</a></span></li><li><span><a href="#Segmentation-into-beats" data-toc-modified-id="Segmentation-into-beats-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Segmentation into beats</a></span></li><li><span><a href="#Identify-dicrotic-notch-and-diastolic-peak" data-toc-modified-id="Identify-dicrotic-notch-and-diastolic-peak-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Identify dicrotic notch and diastolic peak</a></span></li></ul></li><li><span><a href="#Feature-extraction" data-toc-modified-id="Feature-extraction-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Feature extraction</a></span><ul class="toc-item"><li><span><a href="#Features" data-toc-modified-id="Features-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Features</a></span></li><li><span><a href="#Normalize--to-0-mean-and-variance" data-toc-modified-id="Normalize--to-0-mean-and-variance-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Normalize  to 0 mean and variance</a></span></li></ul></li><li><span><a href="#Prepare-dataset" data-toc-modified-id="Prepare-dataset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Prepare dataset</a></span></li><li><span><a href="#Model" data-toc-modified-id="Model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Model</a></span></li></ul></div>

# %%
import numpy as np
import pandas as pd
import scipy as sc

from scipy.signal import butter, filtfilt, find_peaks, peak_prominences
from scipy import integrate
from sklearn.preprocessing import normalize, StandardScaler, MinMaxScaler

from matplotlib import pyplot as plt

# %% [markdown]
# This notebook attempts blood pressure estimation from rPPG signal (remote PPG). On the basis of https://arxiv.org/pdf/1705.04524v3.pdf article here LSTMs are used on extracted features from signal.
#
# The PPG measures the discoloration of the skin as blood perfuses through the capillaries and arteries after each heartbeat. The signal consists of the systolic peak, dicrotic notch, and the diastolic peak. When extracting heart beats, the systolic peaks are used.

# %% [markdown]
# # Load data

# %%
def read_data(path, idxs):
    '''
    Returns array of signals from path directory. Filenames should be indexes stored in idxs argument (303.csv -> [303]). 
    Shape is (n_s, l_s), where n_s - number of signals in directory, l_s - samples in signal
    '''
    data = [pd.read_csv(path + str(idx) +".csv")["pos"].to_numpy() for idx in idxs]
    
    return data

# %%
train_info = pd.read_csv("../data/train/info.csv")

test_info = pd.read_csv("../data/test/info.csv")

# %%
train_info.head()
# Out:
#    sampleID  systolic_pressure  diastolic_pressure  pulse_pressure  \
# 0       293              121.0                69.0            52.0
# 1       295              117.0                70.0            47.0
# 2       303              118.0                64.0            54.0
# 3       315              123.0                71.0            52.0
# 4       316              127.0                74.0            53.0
#
#    mean_arterial_pressure  subject_id
# 0               86.333333         4.0
# 1               85.666667         4.0
# 2               82.000000         4.0
# 3               88.333333         4.0
# 4               91.666667         4.0

# %%
y_train = np.array([train_info['systolic_pressure'].values, train_info['diastolic_pressure'].values]).T
idx_train = train_info['sampleID'].values

y_test = np.array([test_info['systolic_pressure'].values, test_info['diastolic_pressure'].values]).T
idx_test = test_info['sampleID'].values

# %%
train_data = read_data("../ml_assignment_data/train/rPPG/", idx_train)
test_data = read_data("../ml_assignment_data/test/rPPG/", idx_test)

# %%
# checking blood pressure data distribution
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.hist(train_info['systolic_pressure'], bins=22, label='systolic')
plt.hist(train_info['diastolic_pressure'], bins=22, label='diastolic')
plt.title("Train data")
plt.legend()

plt.subplot(1,2,2)
plt.hist(test_info['systolic_pressure'], bins=22, label='systolic')
plt.hist(test_info['diastolic_pressure'], bins=22, label='diastolic')
plt.title("Test data")
plt.legend()

# %% [markdown]
# Functions will be tested on single signal from 303.csv file

# %%
# SAMPLE TO TEST
df = pd.read_csv("../ml_assignment_data/train/rPPG/303.csv")

# %% [markdown]
# # Preprocessing
# ## Filtering
#
# Signals need to be filtered before extracting relevant features. Using 4 order Butterworth filter with cutoff 0.5 - 4Hz, which is a standard for PPG signal. Applied foward and backward filtering using filtfilt() scipy function.

# %%
def sampling_freq(signal, time=120):
    ''' Returns ampling frequency of the signal (as it may differ between recordings)'''
    
    return int(len(signal)/time)

def butter_bandpass(lowcut, highcut, fs, order=4):
    ''' Returns butterworth bandpass filter for parameters '''
    
    # nyquist freq - half of the sampling frequency
    nyq = 0.5 * fs
    
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    
    return b, a

def apply_filtering(signal):
    ''' Returns filtered signal '''
    # sampling freq
    fs = sampling_freq(signal)
    b, a = butter_bandpass(0.5, 4, fs, order=4)
    
    return filtfilt(b, a, signal)

# %%
# Apply butterworth filtering
fil = apply_filtering(df["pos"].values)

# %%
# Visualize signal before and after filtering
plt.figure(figsize=(17,6))

plt.plot(fil, label="filtered PPG")
plt.plot(df["pos"], c='gray', alpha=0.4, label="raw PPG")
plt.title("Filtered PPG signal", fontsize=14)
plt.xlabel("Samples", fontsize=14)
plt.ylabel("Amplitude", fontsize=14)
plt.legend(prop={'size':14})
plt.xlim(0,500)
# Out:
# (0.0, 500.0)

# %% [markdown]
# The noise is significantly reduced. However further filtering might help to smooth out peaks (merge into one, those who are "separated") and result in better systolic peak detection. (median filter, convolve?)

# %% [markdown]
# ## Segmentation into beats
# Signal must be segmented into single beats. Beats are determined by tfns points. Before segmentation those points, including systolic peaks must be detected.
# * For systolic peaks detection I tried to use heartpy toolkit, designed for PPG data to get systolic peaks, but somehow simple find_peaks() from scipy worked better.
# * To get single beat I used local minima extraction that should be start/end of the beats. So they would be tfn points in the article.
# * Then check if between two tfn points there is systolic beat. If the condition is met it's a beat.
# * Each beat is normlized to 1-0 values

# %%
def systolic_peaks(signal):
    ''' Returns list of found systolic peaks in whole signal. Identified as maxima. Required distance between peaks set to 22'''
    return find_peaks(signal, distance=22)[0]

def tfn_points(signal):
    ''' Returns list of tfn points (beats boundaries) as minimums of signal with distance min 25 between eachother'''
    
    # here I use reverted signal and get peaks above 0 
    return find_peaks(signal*(-1), height=0, distance=25)[0]

def beat_segmentation(signal):
    
    ''' Returns list of beats from signal and list of corresponding systolic peak index'''
    
    systolics = systolic_peaks(signal)
    tfns = tfn_points(signal)
    
    beats, systolic = [], []
    
    for i in range(len(tfns)-1):
        start = tfns[i]
        end = tfns[i+1]
        segment = np.arange(start, end)
        l = [f in systolics for f in segment]
        
        # if there is only one systolic peak between minima its a beat
        if list(map(bool, l)).count(True) == 1: 
            # apply normalization, reshaping is required
            bshape = signal[segment].shape
            normalized_beat = normalize(signal[segment].reshape(1, -1))
            beats.append(normalized_beat.reshape(bshape))
            systolic.append(np.where(l)[0][0])
            
    
    return beats, systolic

# %%
# Visualize detection of points
systolics = systolic_peaks(fil)
tfns = tfn_points(fil)


plt.figure(figsize=(17,6))
plt.plot(fil, c="r", alpha=0.6)

plt.scatter(systolics, fil[systolics], c="g", label="systolic peaks")
plt.scatter(tfns, fil[tfns], c="m", label="tfn")
plt.legend(prop={'size':16})
plt.xlim(1500,2000)
# Out:
# (1500.0, 2000.0)

# %%
beats, systolics = beat_segmentation(fil)

# %% [markdown]
# ## Identify dicrotic notch and diastolic peak
# Two other critical points that must be detected before feature extraction are diastolic peaks and dicrotic notch. If a beat doesn't have those points indetified it's impossible to calculate some of the features. They are harder to find in signal than systolics and tfns, especially on the extact positions in noisy signal. Proposed methods:
# * dicrotic notch - maximum of beat second derivative (starting from systolic peak). If more than one such point is identified, the one that occurs later in signal is taken.
# * diastolic peak - maximum of inverted second order derivative of the part of the beat after systolic peak. Point is classified as dystolic peak if it's value bigger than 1% of the preceeding value. Inspiration reference: https://affect.media.mit.edu/pdfs/14.McDuff_et_al_Remote.pdf
# ![image.png](attachment:image.png)

# %%
def dicrotic_notch(beat, systolic):
    '''Returns index of detected dicrotic notch in a beat. If not found returns 0'''
    
    derviative = np.diff(np.diff(beat[systolic:]))
    point = find_peaks(derviative)[0]
    corrected = 0
    
    if len(point) > 0:
        corrected =  systolic + point[-1]
        
    return corrected

def diastolic_peak(beat, systolic):
    '''Returns index of detected diastolic peak in a beat. If not found returns 0'''
   
    derviative = np.diff(np.diff(beat[systolic:]))
    point = find_peaks(derviative*(-1))[0]
    corrected = 0
    
    if len(point) > 0:
        corrected = systolic + point[-1]
        if abs(beat[corrected]) >= abs(1.01*beat[corrected - 1]):
            return corrected
        else: return 0
        
    return corrected

# %%
def peaks_detection(beats, systolics):
    '''Returns created dataframe with beat values and critical points indices'''
    
    dicrotics = []
    diastolics = []
    
    for b, s in zip(beats, systolics):
        tnn = dicrotic_notch(b,s)
        tdn = diastolic_peak(b,s)
        
        dicrotics.append(tnn)
        diastolics.append(tdn)
    
    result = np.array([beats, systolics, dicrotics, diastolics], dtype=object)
    # remove those where dicrotics and diastolics weren't found
    result = result[..., result[2] > 0]
    result = result[..., result[3] > 0]
    
    # output shape is (4, nb) where nb is number of beats
    return result.T

# %%
beats_features = peaks_detection(beats, systolics)

# %%
# Visualize detected peaks
for beat, systolic, dicrotic, diastolic in beats_features:
    plt.figure()
    plt.plot(beat)
    plt.scatter(systolic,beat[systolic], c="g")
    plt.scatter(diastolic,beat[diastolic], c= "r")
    plt.scatter(dicrotic,beat[dicrotic], c= "gray")
    plt.show()

# %% [markdown]
# # Feature extraction
#
# ## Features
# Features are extracted based on peak localization for single beat. Heart rate is the based on whole signal however instead of beats (based on systolic points - regardless if after single points notch/diastolics are detected). Features used in the article are as follows:
#
# - Heart rate: $HR$
# - Reflection index: $RI = b/a$
# - Systolic timespan: $ST = tn_n − tf_n$
# - Up time: $ upTime = tp_n − tf_n$
# - Systolic volume: $SV = \int_{tf_{n}}^{tn{n}} PPG(t)dt$
# - Diastolic volume: $DV = \int^{tf_{n+1}}_{tn{n}} PPG(t)dt$

# %%
def heart_rate(signal, fs):
    ''' Number of systolic peaks per minute. Normal between 60-100 bpm'''
    
    sys = systolic_peaks(signal)
    T = len(signal)/fs
    
    return len(sys)/(T/60)

def reflection_index(beat, systolic, diastolic):
    ''' Returns reflection index which is systolic amplitude to systolic-diastolic amplitude ratio'''
    
    a = beat[systolic] - np.min(beat)
    b = a - (beat[diastolic] - np.min(beat))
    
    return a/b

def systolic_timespan(dicrotic, fs):
    ''' Returns systolic beat timespan in seconds (dicrotic peak marks its end)'''
    
    return dicrotic/fs

def up_time(systolic, fs):
    ''' Returns time to systolic peak in seconds '''
    
    return systolic/fs
    
def systolic_volume(beat, dicrotic, fs):
    ''' Returns systolic volume as area under the curve '''
    
    return integrate.simps(beat[:dicrotic], dx=1/fs)
    
def diastolic_volume(beat, dicrotic, fs):
    ''' Returns diastolic volume as area under the curve '''
    
    return integrate.simps(beat[dicrotic:], dx=1/fs)

# %%
def extract_features(signal, beats_arr, fs):
    '''Extract features from beat array consisting of beat values, systolic peak index, dicrotic notch index and diastolic peak index'''
    
    features = []
    
    hr = heart_rate(signal, fs)
    
    for beat, systolic, dicrotic, diastolic in beats_arr:
        
        ri = reflection_index(beat, systolic, diastolic)
        st = systolic_timespan(dicrotic, fs)
        ut = up_time(systolic, fs)
        sv = systolic_volume(beat, dicrotic, fs)
        dv = diastolic_volume(beat, dicrotic, fs)

        features.append([hr, ri, st, ut, sv, dv])
    
    # return shape should be (Tx, 6)
    return np.array(features)

# %%
fs = sampling_freq(fil)
features = extract_features(fil, beats_features, fs)
features.shape
# Out:
# (82, 6)

# %% [markdown]
# # Prepare dataset
#
# Scaling the data seemed like a challenge, I was confused at the beginning. This article partly helped me to figure things out https://machinelearningmastery.com/how-to-scale-data-for-long-short-term-memory-networks-in-python/.
#
#
# The input must be scaled, it has different ranges (higher for heart rate for example). Figuring out how to apply it to different shapes in dimension was tricky, but standard scaler seems to be fitted for every feature, I used partial_fit when preparing the training data and then iterating over ready X to transform it.
#
# The output was normalized to (0,1] by MinMaxScaler. From the article I would use standarization as the distribution seems normal, but normalizing was used in the article.

# %%
def process_signal(data, scaler, fit=True):
    ''' Process single signal function, returns normlized features after filtering signal and beat segmentation '''
    
    fs = sampling_freq(data)
    
    filtered = apply_filtering(data)
    beats, sys = beat_segmentation(filtered)
    peaks = peaks_detection(beats, sys)
    features = extract_features(filtered, peaks, fs)
    #norm = norm_zeromean(features)
    if fit:
        scaler.partial_fit(features)
    
    return features

def prepare_dataset(data, scaler, fit=True):
    ''' Perform processing all signals in the dataset '''
    
    X = np.array([process_signal(sample, scaler, fit) for sample in data])
    
    
    return X

# %%
scaler = StandardScaler()

X = prepare_dataset(train_data, scaler)
X_test = prepare_dataset(test_data, scaler, False)
# Out:
# C:\Users\alicj\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# C:\Users\alicj\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
for x in X:
    scaler.transform(x, copy=False)
    
for x in X_test:
    scaler.transform(x, copy=False)

# %%
def prepare_y(y_train, y_test):
    
    ''' Scale output blood pressure values by min max, for SBP and DBP respectively '''
    
    n_train, _ = y_train.shape
    n_test, _ = y_test.shape
    
    scaler_sbp = MinMaxScaler()
    
    sbp_train = scaler_sbp.fit_transform(y_train[:,0].reshape(n_train, 1))
    sbp_test = scaler_sbp.transform(y_test[:,0].reshape(n_test,1))
    
    scaler_dbp = MinMaxScaler()
    
    dbp_train = scaler_dbp.fit_transform(y_train[:,1].reshape(n_train,1))
    dbp_test = scaler_dbp.transform(y_test[:,1].reshape(n_test,1))
    
    return np.column_stack((sbp_train, dbp_train)), np.column_stack((sbp_test, dbp_test)), scaler_sbp, scaler_dbp


def invert_y(y, scaler_sbp, scaler_dbp):
    
    ''' Invert scaled y values to blood pressure unit mmHg'''
    
    n, _ = y.shape
    
    sbp = scaler_sbp.inverse_transform(y[:,0].reshape(n,1))
    dbp = scaler_dbp.inverse_transform(y[:,1].reshape(n,1))
    
    return np.column_stack((sbp, dbp))

# %%
y_trainsc, y_testsc, scalersbp, scalerdbp = prepare_y(y_train, y_test)

# %% [markdown]
# # Model
#
# As the data is time series sequence RNN is the best choice.
# Model was built in keras. Inspired by the article, but not exact. Same as described in it bidirectional LSTM is used as the first layer. Oher layers consist of normal LSTM cells.
# X must be of dimension (m, Tx, n_values)
# (291, beats, 6).
#
# Input of LSTM must be (Tx, n_values). Because they must be of same length padding with zeros is introduced. They are not padded to maximum length, but rather chosen 32 timesteps value - as in the article.
#
# Residual connection is introduced to help with vanishing gradient problem.

# %%
from keras.layers import Dense, LSTM, Dropout, Bidirectional, Add, Masking
from tensorflow.keras import Input, Model
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError

from keras.preprocessing.sequence import pad_sequences

# %%
Xpad = pad_sequences(X, maxlen=64, padding='post', dtype='float64')
X_testpad = pad_sequences(X_test, maxlen=64, padding='post', dtype='float64')

# %%
print(f"X Input data shape: {X.shape}")
print(f"After padding X data shape: {np.array(Xpad).shape}")
print(f"y_train data shape: {y_train.shape}")
# Out:
# X Input data shape: (291,)
# After padding X data shape: (291, 64, 6)
# y_train data shape: (291, 2)

# %%
max_time = Xpad.shape[1]
n_features = 6

# %%
inputs = Input(shape=(max_time, n_features))

x = Masking(mask_value=0, input_shape=(max_time, n_features))(inputs)

x = Bidirectional(LSTM(128, return_sequences=True))(x)
x = Dropout(rate=0.5)(x)

x = LSTM(128, return_sequences=True)(x)
x = Dropout(rate=0.5)(x)

x_shortcut2 = LSTM(128, return_sequences=True)(x)
x_shortcut2 = Dropout(rate=0.5)(x_shortcut2)
x = Add()([x, x_shortcut2])

x_shortcut3 = LSTM(128, return_sequences=True)(x)
x_shortcut3 = Dropout(rate=0.5)(x_shortcut3)
x = Add()([x, x_shortcut3])

x = LSTM(128, return_sequences=False)(x)
x = Dropout(rate=0.5)(x)

outputs = Dense(units=2, activation='relu')(x)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 6)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 256)         138240
# _________________________________________________________________
# dropout (Dropout)            (None, None, 256)         0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 128)         197120
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 128)         0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 128)         131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 128)         0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 598,786
# Trainable params: 598,786
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Adam optimizer
opt = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, decay=0.01)

model.compile(optimizer=opt, loss='mean_absolute_error', metrics=[RootMeanSquaredError()])

# %%
history = model.fit(Xpad, y_trainsc, batch_size=64, epochs=50)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 62s 931ms/step - loss: 0.3731 - root_mean_squared_error: 0.4304
# Epoch 2/50
# 5/5 [==============================] - 5s 953ms/step - loss: 0.2962 - root_mean_squared_error: 0.3603
# Epoch 3/50
# 5/5 [==============================] - 5s 957ms/step - loss: 0.2391 - root_mean_squared_error: 0.2979
# Epoch 4/50
# 5/5 [==============================] - 5s 943ms/step - loss: 0.2082 - root_mean_squared_error: 0.2650
# Epoch 5/50
# 5/5 [==============================] - 5s 962ms/step - loss: 0.1867 - root_mean_squared_error: 0.2352
# Epoch 6/50
# 5/5 [==============================] - 5s 960ms/step - loss: 0.1768 - root_mean_squared_error: 0.2240
# Epoch 7/50
# 5/5 [==============================] - 5s 956ms/step - loss: 0.1743 - root_mean_squared_error: 0.2176
# Epoch 8/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1610 - root_mean_squared_error: 0.2040
# Epoch 9/50
# 5/5 [==============================] - 5s 983ms/step - loss: 0.1643 - root_mean_squared_error: 0.2094
# Epoch 10/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1624 - root_mean_squared_error: 0.2028
# Epoch 11/50
# 5/5 [==============================] - 5s 960ms/step - loss: 0.1611 - root_mean_squared_error: 0.2041
# Epoch 12/50
# 5/5 [==============================] - 5s 980ms/step - loss: 0.1591 - root_mean_squared_error: 0.2014
# Epoch 13/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1530 - root_mean_squared_error: 0.1947
# Epoch 14/50
# 5/5 [==============================] - 5s 949ms/step - loss: 0.1564 - root_mean_squared_error: 0.1962
# Epoch 15/50
# 5/5 [==============================] - 5s 947ms/step - loss: 0.1557 - root_mean_squared_error: 0.2018
# Epoch 16/50
# 5/5 [==============================] - 5s 989ms/step - loss: 0.1497 - root_mean_squared_error: 0.1922
# Epoch 17/50
# 5/5 [==============================] - 5s 956ms/step - loss: 0.1473 - root_mean_squared_error: 0.1896
# Epoch 18/50
# 5/5 [==============================] - 5s 966ms/step - loss: 0.1467 - root_mean_squared_error: 0.1879
# Epoch 19/50
# 5/5 [==============================] - 5s 883ms/step - loss: 0.1507 - root_mean_squared_error: 0.1912
# Epoch 20/50
# 5/5 [==============================] - 5s 915ms/step - loss: 0.1530 - root_mean_squared_error: 0.1940
# Epoch 21/50
# 5/5 [==============================] - 5s 982ms/step - loss: 0.1460 - root_mean_squared_error: 0.1896
# Epoch 22/50
# 5/5 [==============================] - 5s 989ms/step - loss: 0.1484 - root_mean_squared_error: 0.1878
# Epoch 23/50
# 5/5 [==============================] - 5s 987ms/step - loss: 0.1424 - root_mean_squared_error: 0.1828
# Epoch 24/50
# 5/5 [==============================] - 5s 999ms/step - loss: 0.1512 - root_mean_squared_error: 0.1965
# Epoch 25/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1442 - root_mean_squared_error: 0.1843
# Epoch 26/50
# 5/5 [==============================] - 5s 962ms/step - loss: 0.1451 - root_mean_squared_error: 0.1837
# Epoch 27/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1438 - root_mean_squared_error: 0.1835
# Epoch 28/50
# 5/5 [==============================] - 5s 991ms/step - loss: 0.1434 - root_mean_squared_error: 0.1849
# Epoch 29/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1425 - root_mean_squared_error: 0.1839
# Epoch 30/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1464 - root_mean_squared_error: 0.1869
# Epoch 31/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1421 - root_mean_squared_error: 0.1810
# Epoch 32/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1477 - root_mean_squared_error: 0.1896
# Epoch 33/50
# 5/5 [==============================] - 5s 978ms/step - loss: 0.1432 - root_mean_squared_error: 0.1826
# Epoch 34/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1440 - root_mean_squared_error: 0.1850
# Epoch 35/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1425 - root_mean_squared_error: 0.1816
# Epoch 36/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1465 - root_mean_squared_error: 0.1889
# Epoch 37/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1461 - root_mean_squared_error: 0.1883
# Epoch 38/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1393 - root_mean_squared_error: 0.1810
# Epoch 39/50
# 5/5 [==============================] - 5s 974ms/step - loss: 0.1439 - root_mean_squared_error: 0.1853
# Epoch 40/50
# 5/5 [==============================] - 5s 970ms/step - loss: 0.1408 - root_mean_squared_error: 0.1817
# Epoch 41/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1457 - root_mean_squared_error: 0.1841
# Epoch 42/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1389 - root_mean_squared_error: 0.1783
# Epoch 43/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1393 - root_mean_squared_error: 0.1801
# Epoch 44/50
# 5/5 [==============================] - 5s 987ms/step - loss: 0.1480 - root_mean_squared_error: 0.1871
# Epoch 45/50
# 5/5 [==============================] - 5s 999ms/step - loss: 0.1348 - root_mean_squared_error: 0.1723
# Epoch 46/50
# 5/5 [==============================] - 5s 997ms/step - loss: 0.1433 - root_mean_squared_error: 0.1841
# Epoch 47/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1388 - root_mean_squared_error: 0.1775
# Epoch 48/50
# 5/5 [==============================] - 5s 982ms/step - loss: 0.1387 - root_mean_squared_error: 0.1799
# Epoch 49/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1385 - root_mean_squared_error: 0.1787
# Epoch 50/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1334 - root_mean_squared_error: 0.1755

# %%
# make predictions
train_predict = model.predict(Xpad)
test_predict = model.predict(X_testpad)

# invert scaled values to blood pressure unit mmHg
train_pred_invert = invert_y(train_predict, scalersbp, scalerdbp)
test_pred_invert = invert_y(test_predict, scalersbp, scalerdbp)

# %%
import math
from sklearn.metrics import mean_squared_error

# calculate root mean squared error on real values
train_score_sbp = math.sqrt(mean_squared_error(y_train[:,0], train_pred_invert[:,0]))
train_score_dbp = math.sqrt(mean_squared_error(y_train[:,1], train_pred_invert[:,1]))
print('Train Score RMSE [mmHg]: \n SBP %.2f \n DBP %.2f' % (train_score_sbp, train_score_dbp))

test_score_sbp = math.sqrt(mean_squared_error(y_test[:,0], test_pred_invert[:,0]))
test_score_dbp = math.sqrt(mean_squared_error(y_test[:,1], test_pred_invert[:,1]))
print('Test Score RMSE [mmHg]: \n SBP %.2f \n DBP %.2f' % (test_score_sbp, test_score_dbp))
# Out:
# Train Score RMSE [mmHg]:
#  SBP 15.74
#  DBP 10.54
# Test Score RMSE [mmHg]:
#  SBP 15.74
#  DBP 11.52

# %%
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], c='m')
plt.grid()
plt.ylabel('MAE',fontsize=16)
plt.xlabel('Epoch', fontsize=16)
# Out:
# Text(0.5, 0, 'Epoch')

# %%
plt.figure(figsize=(20,10))

plt.subplot(2,2,3)
axisy = np.arange(len(train_pred_invert[:,1]))
plt.scatter(axisy,y_train[:,1], label='true')
plt.scatter(axisy,train_pred_invert[:,1], label='predicted')
plt.title('Train DBP')
plt.ylim(20,115)
plt.legend()

plt.subplot(2,2,4)
axisy = np.arange(len(test_pred_invert[:,1]))
plt.scatter(axisy, y_test[:,1], label='true')
plt.scatter(axisy,test_pred_invert[:,1], label='predicted')
plt.title('Test DBP')
plt.ylim(20,115)
plt.legend()


plt.subplot(2,2,1)
axisy = np.arange(len(train_pred_invert[:,0]))
plt.scatter(axisy,y_train[:,0], label='true')
plt.scatter(axisy, train_pred_invert[:,0], label='predicted')
plt.title('Train SBP')
plt.ylim(70,180)
plt.legend()

plt.subplot(2,2,2)
axisy = np.arange(len(test_pred_invert[:,0]))
plt.scatter(axisy, y_test[:,0], label='true')
plt.scatter(axisy,test_pred_invert[:,0], label='predicted')
plt.title('Test SBP')
plt.ylim(70,180)
plt.legend()
